# %% [markdown]
# # 02465  Introduction to reinforcement learning and control - Exam
#
# **Student number:** s253790
#
# uv run jupyter nbconvert --to html 02465_exam.ipynb

# %% [markdown]
# # Question 1
#
# ## Answer
#
# ...

# %% [markdown]
# # Question 2
#
# ## Answer
#
# ...

# %% [markdown]
# # Question 3
#
# ## Answer
#
# ...
